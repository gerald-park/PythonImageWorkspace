# %%
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows 
matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 마이너스 깨짐 방지

# %%
labels = ['강백호', '서태웅', '정대만'] #이름
values = [190, 187, 184]
plt.bar(labels,values, color = 'r')
# Out:
# <BarContainer object of 3 artists>

# %%
labels = ['강백호', '서태웅', '정대만'] #이름
values = [190, 187, 184]
colors = ['r', 'g', 'b']
plt.bar(labels,values, color = colors, alpha=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(labels,values, color = colors, alpha=0.5)
plt.ylim(175,195)
# Out:
# (175.0, 195.0)

# %%
plt.bar(labels,values, color = colors, alpha=0.5, width=0.3)
plt.ylim(175,195)
# Out:
# (175.0, 195.0)

# %%
plt.bar(labels,values, color = colors, alpha=0.5, width=0.3)
plt.ylim(175,195)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# Out:
# (array([175., 180., 185., 190., 195.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
labels = ['강백호', '서태웅', '정대만'] #이름
values = [190, 187, 184]
ticks = ['1번학생','2번학생','3번학생']
plt.bar(labels,values, color = colors, alpha=0.5, width=0.3)
plt.xticks(labels,ticks)
# Out:
# ([<matplotlib.axis.XTick at 0x7f9a986013a0>,
#   <matplotlib.axis.XTick at 0x7f9a98601370>,
#   <matplotlib.axis.XTick at 0x7f9a985f9f40>],
#  [Text(0.0, 0, '1번학생'), Text(1.0, 0, '2번학생'), Text(2.0, 0, '3번학생')])

# %%
plt.barh(labels,values, color = colors)
plt.xlim(175,195)
# Out:
# (175.0, 195.0)

# %% [markdown]
# ## Hatch
# https://matplotlib.org/stable/gallery/shapes_and_collections/hatch_style_reference.html

# %%
bar = plt.bar(label, values)
bar[0].set_hatch('/')
bar[1].set_hatch('x')
bar[2].set_hatch('..')

# %%
bar = plt.bar(labels, values)
plt.ylim(175,195)
for idx,rect in enumerate(bar):
    plt.text(idx, rect.get_height(), values[idx], ha='center')
